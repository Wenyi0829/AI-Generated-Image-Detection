# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/NPR
# Out:
# /content/drive/MyDrive/NPR

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: opencv_python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.12.0.88)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.23.0+cu126)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.2.0->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.2.0->-r requirements.txt (line 6)) (3.0.3)

# %%
# !pip install gdown==4.7.1
# Out:
# Collecting gdown==4.7.1
#   Downloading gdown-4.7.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown==4.7.1) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown==4.7.1) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from gdown==4.7.1) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown==4.7.1) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown==4.7.1) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==4.7.1) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown==4.7.1) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==4.7.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==4.7.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==4.7.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==4.7.1) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown==4.7.1) (1.7.1)
# Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# Successfully installed gdown-4.7.1

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (25.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.4

# %%
# !pip install transforms
# Out:
# Collecting transforms
#   Downloading transforms-0.2.1-py3-none-any.whl.metadata (1.8 kB)
# Downloading transforms-0.2.1-py3-none-any.whl (18 kB)
# Installing collected packages: transforms
# Successfully installed transforms-0.2.1

# %%
# !python train.py --model_path ./NPR.pth
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 64
#                     beta1: 0.9
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: adm,biggan,glide,midjourney,sdv5,vqdm,wukong
#            continue_train: False
#                  cropSize: 224
#                  data_aug: False
#                  dataroot: ./genimage
#                 delr_freq: 10
#           earlystop_epoch: 10
#                     epoch: latest
#               epoch_count: 1
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: True                          	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                last_epoch: -1
#                  loadSize: 256
#                 loss_freq: 400
#                        lr: 0.0002
#                      mode: binary
#                      name: 7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong2025_11_13_06_30_09	[default: 7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong]
#                 new_optim: False
#                     niter: 20
#                   no_flip: False
#               num_threads: 8
#                     optim: adam
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#           save_epoch_freq: 1
#          save_latest_freq: 2000
#            serial_batches: False
#                    suffix:
#               train_split: train
#                 val_split: val
# ----------------- End -------------------
# train.py  --model_path  ./NPR.pth
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# cwd: /content/drive/MyDrive/NPR
# 2025_11_13_06_59_21 Train loss: 0.44924795627593994 at step: 400 lr 0.0002
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0250, 0.9996]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 64.11%
#   - Precision: 80.29%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 84.26%
#   - Precision: 70.13%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 74.19%
#   - Average Precision: 86.25%
# ==================================================
# (Val @ epoch 0) acc: 0.7418571428571429; ap: 0.8625426533772302
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_07_15_27 Train loss: 0.45736193656921387 at step: 800 lr 0.0002
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0200, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 38.69%
#   - Precision: 93.83%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 97.46%
#   - Precision: 61.38%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_08_30_07 Train loss: 0.1232793927192688 at step: 5200 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 92.20%
#   - Precision: 97.40%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 97.54%
#   - Precision: 92.60%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 94.87%
#   - Average Precision: 99.15%
# ==================================================
# (Val @ epoch 11) acc: 0.9487142857142857; ap: 0.9915496820684301
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_08_37_00 Train loss: 0.1094323992729187 at step: 5600 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 98.17%
#   - Precision: 94.86%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 94.69%
#   - Precision: 98.11%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 96.43%
#   - Average Precision: 99.48%
# ==================================================
# (Val @ epoch 12) acc: 0.9642857142857143; ap: 0.9948132564608501
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_08_43_56 Train loss: 0.047056280076503754 at step: 6000 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 97.43%
#   - Precision: 93.25%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 92.94%
#   - Precision: 97.31%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 95.19%
#   - Average Precision: 99.22%
# ==================================================
# (Val @ epoch 13) acc: 0.9518571428571428; ap: 0.9922161016840699
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_08_50_50 Train loss: 0.12008000910282135 at step: 6400 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 96.89%
#   - Precision: 95.55%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 95.49%
#   - Precision: 96.84%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 96.19%
#   - Average Precision: 99.43%
# ==================================================
# (Val @ epoch 14) acc: 0.9618571428571429; ap: 0.994265191452601
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_08_57_45 Train loss: 0.13996390998363495 at step: 6800 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 95.46%
#   - Precision: 98.12%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 98.17%
#   - Precision: 95.58%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 96.81%
#   - Average Precision: 99.61%
# ==================================================
# (Val @ epoch 15) acc: 0.9681428571428572; ap: 0.9961383705203632
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_09_04_42 Train loss: 0.03428957611322403 at step: 7200 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 97.11%
#   - Precision: 96.18%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 96.14%
#   - Precision: 97.09%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 96.63%
#   - Average Precision: 99.42%
# ==================================================
# (Val @ epoch 16) acc: 0.9662857142857143; ap: 0.9942456507736109
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_09_11_30 Train loss: 0.09448591619729996 at step: 7600 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 98.06%
#   - Precision: 96.76%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 96.71%
#   - Precision: 98.03%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 97.39%
#   - Average Precision: 99.63%
# ==================================================
# (Val @ epoch 17) acc: 0.9738571428571429; ap: 0.9962506371410517
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_09_18_26 Train loss: 0.17664213478565216 at step: 8000 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 97.23%
#   - Precision: 96.65%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 96.63%
#   - Precision: 97.21%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 96.93%
#   - Average Precision: 99.54%
# ==================================================
# (Val @ epoch 18) acc: 0.9692857142857143; ap: 0.9953966196558757
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2025_11_13_09_25_30 Train loss: 0.10313255339860916 at step: 8400 lr 0.00018
# Found classes: ['adm', 'biggan', 'glide', 'midjourney', 'sdv5', 'vqdm', 'wukong']
# Total samples: 7000
# Real images (label 0): 3500
# Fake images (label 1): 3500
# Unique labels: [0 1]
# Predictions range: [0.0000, 1.0000]
#
# ==================================================
# PER-CLASS METRICS:
# ==================================================
# Real Images (Class 0):
#   - Accuracy: 96.03%
#   - Precision: 98.05%
#   - Support: 3500 samples
#
# Fake Images (Class 1):
#   - Accuracy: 98.09%
#   - Precision: 96.11%
#   - Support: 3500 samples
#
# OVERALL METRICS:
#   - Accuracy: 97.06%
#   - Average Precision: 99.62%
# ==================================================
# (Val @ epoch 19) acc: 0.9705714285714285; ap: 0.99622063681329
# Saving model ./checkpoints/7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong2025_11_13_06_30_09/model_epoch_last.pth

# %%
# !python val.py --model_path ./checkpoints/final/model_epoch_last.pth
# Out:
# ----------------- Options ---------------
#                      arch: res50
#                batch_size: 64
#                 blur_prob: 0
#                  blur_sig: 0.5
#           checkpoints_dir: ./checkpoints
#                 class_bal: False
#                   classes: adm,biggan,glide,midjourney,sdv5,vqdm,wukong
#                  cropSize: 224
#                  dataroot: ./genimage/val
#                 delr_freq: 10
#           earlystop_epoch: 15
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                   isTrain: False                         	[default: None]
#                jpg_method: cv2
#                  jpg_prob: 0
#                  jpg_qual: 75
#                  loadSize: 256
#                        lr: 2e-05
#                      mode: binary
#                model_path: ./checkpoints/7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong2025_11_13_06_30_09/model_epoch_last.pth	[default: ./checkpoints/base/model_epoch_last.pth]
#                      name: 7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong2025_11_13_09_33_42	[default: 7class-adm-biggan-glide-midjourney-sdv5-vqdm-wukong]
#                     niter: 0
#                   no_crop: False
#                   no_flip: False
#                 no_resize: False
#               num_threads: 8
#            resize_or_crop: scale_and_crop
#                 rz_interp: bilinear
#            serial_batches: False
#                    suffix:
# ----------------- End -------------------
# Dataset root path: ./genimage/val
# Found subdirectories: ['biggan', 'vqdm', 'sdv5', 'wukong', 'adm', 'glide', 'midjourney']
#   biggan: ['ai', 'nature']
#   vqdm: ['ai', 'nature']
#   sdv5: ['ai', 'nature']
#   wukong: ['ai', 'nature']
#   adm: ['ai', 'nature']
#   glide: ['ai', 'nature']
#   midjourney: ['ai', 'nature']
# Using entire state_dict for model weights
#
# ================================================================================
# VALIDATING ALL CLASSES
# ================================================================================
#
# ============================================================
# VALIDATING: ADM
# ============================================================
# Found 1000 images in ./genimage/val/adm
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for adm:
#   Overall Accuracy: 97.20%
#   Average Precision: 99.78%
#   Real Images Accuracy: 95.80%
#   Fake Images Accuracy: 98.60%
# ============================================================
#
# ============================================================
# VALIDATING: BIGGAN
# ============================================================
# Found 1000 images in ./genimage/val/biggan
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for biggan:
#   Overall Accuracy: 96.80%
#   Average Precision: 99.05%
#   Real Images Accuracy: 96.40%
#   Fake Images Accuracy: 97.20%
# ============================================================
#
# ============================================================
# VALIDATING: GLIDE
# ============================================================
# Found 1000 images in ./genimage/val/glide
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for glide:
#   Overall Accuracy: 97.40%
#   Average Precision: 99.87%
#   Real Images Accuracy: 95.20%
#   Fake Images Accuracy: 99.60%
# ============================================================
#
# ============================================================
# VALIDATING: MIDJOURNEY
# ============================================================
# Found 1000 images in ./genimage/val/midjourney
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for midjourney:
#   Overall Accuracy: 95.90%
#   Average Precision: 99.26%
#   Real Images Accuracy: 97.00%
#   Fake Images Accuracy: 94.80%
# ============================================================
#
# ============================================================
# VALIDATING: SDV5
# ============================================================
# Found 1000 images in ./genimage/val/sdv5
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for sdv5:
#   Overall Accuracy: 97.40%
#   Average Precision: 99.83%
#   Real Images Accuracy: 95.00%
#   Fake Images Accuracy: 99.80%
# ============================================================
#
# ============================================================
# VALIDATING: VQDM
# ============================================================
# Found 1000 images in ./genimage/val/vqdm
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for vqdm:
#   Overall Accuracy: 98.00%
#   Average Precision: 99.91%
#   Real Images Accuracy: 96.40%
#   Fake Images Accuracy: 99.60%
# ============================================================
#
# ============================================================
# VALIDATING: WUKONG
# ============================================================
# Found 1000 images in ./genimage/val/wukong
# Processed 64 samples...
# Processed 704 samples...
# Total samples: 1000
# Real images (label 0): 500
# Fake images (label 1): 500
#
# RESULTS for wukong:
#   Overall Accuracy: 96.70%
#   Average Precision: 99.68%
#   Real Images Accuracy: 96.40%
#   Fake Images Accuracy: 97.00%
# ============================================================
#
# ================================================================================
# SUMMARY ACROSS ALL CLASSES
# ================================================================================
# Average Overall Accuracy: 97.06%
# Average AP: 99.62%
# Average Real Accuracy: 96.03%
# Average Fake Accuracy: 98.09%
#
# Class        Acc(%)   AP(%)    Real_Acc(%)  Fake_Acc(%)  Samples
# ----------------------------------------------------------------------
# adm          97.20    99.78    95.80        98.60        1000
# biggan       96.80    99.05    96.40        97.20        1000
# glide        97.40    99.87    95.20        99.60        1000
# midjourney   95.90    99.26    97.00        94.80        1000
# sdv5         97.40    99.83    95.00        99.80        1000
# vqdm         98.00    99.91    96.40        99.60        1000
# wukong       96.70    99.68    96.40        97.00        1000
# ================================================================================
#
# VALIDATION COMPLETED!
